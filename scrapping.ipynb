# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.11/dist-packages (1.2.7)

# %%
import pandas as pd
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort, reviews_all

# %%
# Mengambil semua ulasan dari aplikasi dengan ID 'com.byu.id' di Google Play Store.
# Proses scraping mungkin memerlukan beberapa saat tergantung pada jumlah ulasan yang ada.
scrapreview = reviews_all(
    'app.bpjs.mobile',          # ID aplikasi
    lang='id',             # Bahasa ulasan (default: 'en')
    country='id',          # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT, # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=15000             # Jumlah maksimum ulasan yang ingin diambil
)

# %%
# Menyimpan ulasan dalam file CSV
import csv

with open('ulasan_aplikasi.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in scrapreview:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %% [markdown]
# # Loading Dataset

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_aplikasi.csv', index=False)

# %%
# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
# Menampilkan lima baris pertama dari DataFrame app_reviews_df
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  1ae2b4e0-0c90-4bbe-ac35-8f90f6e2ac1c  Pengguna Google
# 1  5e08c4a6-d3f2-43ba-9a47-9332e1c545a0  Pengguna Google
# 2  a07a2d9d-d058-4134-a356-607943185238  Pengguna Google
# 3  806384cb-43fb-4abd-9395-b7e0789153d1  Pengguna Google
# 4  c61fd4a7-b571-452f-9260-7633c9a51006  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Aplikasi macam apa iniiii,mau daftar aja susah...      1            211
# 1  Kenapa eror terus jaringan nya??? Padahal wifi...      1            333
# 2  Untuk registrasi gagal terus, error setelah di...      1            207
# 3  Tolong untuk verifikasi waktu mau daftar akun ...      1            287
# 4  1. Daftar kontrol deket2 hari gabisa karena er...      1             41
#
#   reviewCreatedVersion                  at  \
# 0               4.12.0 2025-03-08 20:53:19
# 1               4.11.2 2025-02-25 07:10:13
# 2               4.12.0 2025-03-08 15:16:34
# 3               4.11.2 2025-02-21 13:00:17
# 4               4.11.2 2025-03-07 03:48:53
#
#                                         replyContent           repliedAt  \
# 0                                               None                 NaT
# 1  Mohon maaf atas ketidaknyamanannya. Terkait ke... 2025-03-07 07:21:36
# 2                                               None                 NaT
# 3  Mohon maaf atas ketidaknyamanannya. Pastikan j... 2025-03-11 04:30:26
# 4                                               None                 NaT
#
#   appVersion
# 0     4.12.0
# 1     4.11.2
# 2     4.12.0
# 3     4.11.2
# 4     4.11.2

# %%
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85500 entries, 0 to 85499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              85500 non-null  object
#  1   userName              85500 non-null  object
#  2   userImage             85500 non-null  object
#  3   content               85500 non-null  object
#  4   score                 85500 non-null  int64
#  5   thumbsUpCount         85500 non-null  int64
#  6   reviewCreatedVersion  70887 non-null  object
#  7   at                    85500 non-null  datetime64[ns]
#  8   replyContent          57670 non-null  object
#  9   repliedAt             57670 non-null  datetime64[ns]
#  10  appVersion            70887 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 7.2+ MB
